# %% [markdown]
# <a href="https://colab.research.google.com/github/Rittikasarakar/Rittikasarakar/blob/main/Data_visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('https://raw.githubusercontent.com/rajeevratan84/datascienceforbusiness/master/titanic.csv',encoding='ISO-8859-1')
df1=pd.read_csv('https://raw.githubusercontent.com/rajeevratan84/datascienceforbusiness/master/winequalityN.csv',encoding='ISO-8859-1')
df1
#df1.info()
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            7.0             0.270         0.36            20.7
# 1     white            6.3             0.300         0.34             1.6
# 2     white            8.1             0.280         0.40             6.9
# 3     white            7.2             0.230         0.32             8.5
# 4     white            7.2             0.230         0.32             8.5
# ...     ...            ...               ...          ...             ...
# 6492    red            6.2             0.600         0.08             2.0
# 6493    red            5.9             0.550         0.10             2.2
# 6494    red            6.3             0.510         0.13             2.3
# 6495    red            5.9             0.645         0.12             2.0
# 6496    red            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
#plt.plot(x,y)
a=np.arange(1,11)
b=a**2
c=a**3
plt.plot(a,b,color='green',label='square',marker="o",markersize=10,markerfacecolor="red",markeredgecolor="blue")
a
plt.plot(a,c,color='maroon',label='cube',marker='d',markersize=8,markerfacecolor="red",markeredgecolor="yellow")

#plt.xlabel('str')
#plt.ylabel('str')
plt.xlabel('val from 1 to 10')
plt.ylabel('squares from 1 to 10')
a=plt.title('SQUARES')
# plt.show()
#plt.legend()#it will genertrate will

#plt.subplot(3,2,5)
#plt.show()

# %%
#plt.plot(a,b)
#a=np.array([1,8])#if we don't assign x-axis it will take by-default (x=1,2,3,4.....)
# b=np.array([3,10])
# plt.plot(a,b,color="pink")
# plt.xlabel('numbers')
# plt.ylabel('default')
# plt.title('numeric')
# plt.show()

# %%
#plt.subplot(3,2,1)
a = np.arange(1,11)
b = a**2
plt.plot(a,b,color='red')

#plot2
x=np.array([1,9])
y=np.array([2,10])

#plt.subplot(3,3,2)
plt.plot(x,y,label='numbers')
plt.xlabel('int_odd')
plt.ylabel('even_no')

# plt.subplot(3,3,4)
# plt.plot(x,y,color="brown",label="nos")
# plt.legend()
# plt.subplot(3,3,9)
# plt.plot(x,y,color="red")
# plt.show()
# Out:
# Text(0, 0.5, 'even_no')

# %%
#var=plt.figure()
#var1=var.add_axes([left,bottom,width,height])
# var1.plot(x,y)

#figsize=(width,height)
import matplotlib.pyplot as plt
import numpy as np

ob=plt.figure(figsize=(10,10),facecolor='pink')
a=ob.add_axes([0.1,0.1,0.9,0.9])
b=ob.add_axes([0.8,0.8,0.2,0.2])


x=np.arange(1,7)
y=x**2
z=x**3

a.plot(x,y,marker='o',markerfacecolor='black',label="sqr")
a.plot(x,z,marker='o',markerfacecolor='black',label="cube")
a.set_xlabel('Values')
a.set_ylabel('square')
a.set_title('outer')
a.legend()



b.plot(x,y,marker="*",markerfacecolor="yellow",markeredgecolor="black",label="Inner")
b.plot(x,z,marker='o',markerfacecolor='black',label="cube")

# b.set_xlabel("numbers")
# b.set_ylabel("numbers")
# b.set_title('squ')
b.legend(fontsize=10,title='legend title')
plt.show()

# %%
   #var=plt.figure()
#var1=var.add_axes([left,bottom,width,height])
var=plt.figure(figsize=(5,5))
a=var.add_axes([0.1,0,0.9,1])
b=var.add_axes([0.2,0.1,0.7,0.8])
c=var.add_axes([0.55,0.5,0.35,0.4])
x=np.arange(1,7)
y=x**2
z=x**3
a.plot(x,y,marker="d",markerfacecolor="pink",markeredgecolor="black")
b.plot(x,y,marker="*",markerfacecolor="green",markeredgecolor="pink")
c.plot(x,y,marker="o",markerfacecolor="blue",markeredgecolor="black")
a.set_xlabel("values")
a.set_ylabel("value gap by 10")

b.set_title("boxes")
a.set_facecolor('blue')
b.set_facecolor('orange')
a.set_facecolor('green')
c.set_facecolor("pink")

# %%
#var1,var2=plt.subplots(nrows=val,ncols=val)


# var=plt.figure(figsize=(10,5))
# a=np.arange(1,10)
# b=np.arange(10,20)
fig,axis=plt.subplots(nrows=2,ncols=3)
a=np.arange(1,7)
b=np.arange(10,16)

#syntax
# axes[row][col].plot(x,y)

axis[1][1].plot(a,b, c= "black")
axis[1][1].set_xlabel("numbers")
axis[1][1].set_facecolor("b")
# axes[0][0].set_xlabel('val')
# axes[0][0].set_facecolor('pink')

# axes[2][1].plot(x,z)
#axes[1][2].plot(a,b)

# axes[1].plot(x,y)
# axes[1].set_xlabel('val')
# axes[1].set_facecolor('pink')

# %%
#to get data points --> annotate()
x=np.arange(1,7)
y=x**2
plt.plot(x,y,marker='o')

# for i in range(len(x)):
#   plt.annotate(f'({x[i]},{y[i]})',(x[i],y[i]),ha='right')


for i,j in zip(x,y):
  plt.annotate(f'({i},{j})',(i,j), ha= "center")

# %%
plt.axhline(10,color='red',linestyle='dashed',label='y=10')
plt.legend()
plt.axvline(3)
plt.show()

# %%
#piechart
#syntax:  plt.pie(values,labels=val,autopct='val')
labels=['pyM96','pyM98','pyE90','pyE32','pyA04']
no_of_stud=[15,10,20,40,60]
c=['red','green','pink','yellow','grey']
plt.pie(no_of_stud,labels=labels,autopct='%0.2f%%',colors=c)
plt.show()

# %%
# labels=['survived','died']
# sur=df['survived'][df['survived']==1].count()
# die=df['survived'][df['survived']==0].count()
# data=[sur,die]
# c=['green','red']
# plt.pie(data,labels=labels,colors=c,autopct='%0.2f%%')
# plt.show()

# %%
#histogram
#plt.hist(df['col'])---> only 1 col--->
#x-axis: mentioned col
#y-axis: count

#a=plt.hist(df['alcohol'], alpha = 0.20,bins=10)

# %%
plt.hist(df1["alcohol"], bins=20, alpha=0.5, label="alcohol")
plt.hist(df1["pH"], bins=20, alpha=0.5, label="pH")
plt.legend()
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()

# %%
#plt.scatter(df[col],df['col])

plt.scatter(df1['alcohol'],df1['pH'],color='green')
plt.show()

# %%
#df=pd.read_csv('https://raw..com/githubusercontentrajeevratan84/datascienceforbusiness/master/hr_data.csv')
df
#f['department'].unique()
# Out:
#       pclass                                             name     sex  \
# 0          1                    Allen, Miss. Elisabeth Walton  female
# 1          1                   Allison, Master. Hudson Trevor    male
# 2          1                     Allison, Miss. Helen Loraine  female
# 3          1             Allison, Mr. Hudson Joshua Creighton    male
# 4          1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# ...      ...                                              ...     ...
# 1304       3                             Zabour, Miss. Hileni  female
# 1305       3                            Zabour, Miss. Thamine  female
# 1306       3                        Zakarian, Mr. Mapriededer    male
# 1307       3                              Zakarian, Mr. Ortin    male
# 1308       3                               Zimmerman, Mr. Leo    male
#
#           age  sibsp  parch  ticket      fare    cabin embarked  survived
# ...

# %%
label= ["IT","RandD","accounting","hr","management","marketing","product_mng","sales","support","technical"]
d=df.groupby("department")['employee_id'].count()
c=["red","green","yellow","brown","white","pink","orange","green","red","violet"]
plt.pie(d,labels=lab  el,autopct='%0.0f%%',colors=c,pctdistance=0.9)
plt.show()
#print(df)
d=df.groupby("department")['employee_id'].count()
d

# %%
val = df.department.value_counts()

# %%
plt.pie(val , labels = val.index[2] , autopct='%0.0f%%' )

# %%
d

# %%
labels = ["IT","RandD","accounting","hr","management","marketing","product_mng","sales","support","technical"]

# %%
import seaborn as sns

# %%
dff = pd.read_csv('https://raw.githubusercontent.com/rajeevratan84/datascienceforbusiness/master/winequalityN.csv')
dff

# %%
ax=sns.distplot(dff['alcohol'],kde=True,color="green",bins=8)
for i in ax.containers:
  ax.bar_label(i)
#s=sns.displot(dff['alcohol'])
# help(sns)
# ax=sns.jointplot(x="alcohol",y="pH",data=dff)

# %%
#scatter plot

x=np.arange(1,6)
y=x**2

a=[20,30,45,89,78,66]
b=[34,56,90,67,56,45]
plt.scatter(x,y,c = "r")
plt.scatter(a,b, c= "b")

# %%
#1at day of carr

car_age=[5,8,7,8,13,11,4,2,9,15]
print(len(car_age))
car_speed =[90,80,79,82,71,69,91,95,68,54]
print(len(car_speed))


#end day observation
car_age1 =[5,7,9,8,10,4,20,6,3]
print(len(car_age1))
car_speed1=[92,89,84,80,94,47,90,96,91]
print(len(car_speed1))
s=[20,1,2, 5,40,7,7,5,9,11]
#colormap = []
plt.bar(car_age,car_speed)
plt.bar(car_age1, car_speed1)

# %%
#barplot()
x=np.arange(1,6)
y=x**2

a=[20,30,45,89,78,66]
b=[34,56,90,67,56,45]
#plt.bar(x,y, width = 10)
plt.bar(a,b, width = 5)
plt.show()

# %%
x=[10,20,30]
index=["one","two","three"]
index2=[0,0.3,0.1]
plt.pie(x,labels = index, explode = index2,shadow= True, startangle= 360, autopct ="%0.2f%%")
plt.show()
#plt.pie(value, labels=[], explode=)
